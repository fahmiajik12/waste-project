# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Baca file Excel
file_path = "datatimbangan2019-2023_dengan_kecamatan.xlsx"
df = pd.read_excel(file_path)

# 2. Hapus data yang mengandung missing value
df_clean = df.dropna()

# 3. Fungsi untuk menentukan musim berdasarkan bulan
def tentukan_musim(bulan):
    if 4 <= bulan <= 9:
        return "Kemarau"
    else:
        return "Hujan"

# 4. Tambahkan kolom "Musim"
df_clean["Musim"] = df_clean["Bulan"].apply(tentukan_musim)

# 5. EDA: Visualisasi distribusi data berdasarkan musim
musim_counts = df_clean["Musim"].value_counts()
plt.figure(figsize=(6,4))
sns.barplot(x=musim_counts.index, y=musim_counts.values, palette="viridis")
plt.title("Distribusi Data Timbangan per Musim")
plt.xlabel("Musim")
plt.ylabel("Jumlah Data")
plt.tight_layout()
plt.show()

# 6. Simpan hasil ke file Excel baru
df_clean.to_excel("datatimbangan_dengan_musim.xlsx", index=False)

# 1. Tampilkan 5 baris pertama
print("===== HEAD (5 Baris Pertama) =====")
print(df_clean.head(), "\n")

# 2. Dimensi DataFrame
print("===== SHAPE =====")
print(f"Jumlah Baris: {df_clean.shape[0]}, Jumlah Kolom: {df_clean.shape[1]}\n")

# 3. Informasi kolom dan tipe data
print("===== INFO =====")
print(df_clean.info(), "\n")

# 4. Jumlah missing value per kolom
print("===== MISSING VALUES =====")
print(df_clean.isnull().sum(), "\n")

# 5. Statistik deskriptif lengkap
print("===== DESCRIPTIVE STATISTICS =====")
print(df_clean.describe(include='all'), "\n")

# 6. Jumlah nilai unik per kolom
print("===== UNIQUE VALUE COUNTS =====")
for col in df_clean.columns:
    print(f"{col}: {df_clean[col].nunique()} nilai unik")

# 7. Contoh nilai unik untuk kolom kategorik
print("\n===== SAMPLE UNIQUE VALUES (KATEGORIK) =====")
for col in df_clean.select_dtypes(include='object').columns:
    print(f"{col}: {df_clean[col].unique()[:5]}")  # tampilkan hanya 5 nilai unik pertama
# Out:
# /var/folders/mw/d6pj95f17xn1pr6v_zm2dfv40000gn/T/ipykernel_8546/1614584412.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["Musim"] = df_clean["Bulan"].apply(tentukan_musim)
# /var/folders/mw/d6pj95f17xn1pr6v_zm2dfv40000gn/T/ipykernel_8546/1614584412.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=musim_counts.index, y=musim_counts.values, palette="viridis")
# ===== HEAD (5 Baris Pertama) =====
#       Tanggal  Hari  Bulan  Tahun  No. Polisi  Barang               SUPPLIER  \
# 0  07/01/2023     7      1   2023  AA 8013 XA  Sampah     PASAR REJOWINANGUN
# 1  07/01/2023     7      1   2023  AB 9699 WE  Sampah  PERUM DEPKES MAGELANG
# 2  07/01/2023     7      1   2023  AA 8066 XA  Sampah     DEPO TIDAR SELATAN
# 3  07/01/2023     7      1   2023  AA 1975 QH  Sampah    SOROBAYAN BANYUURIP
# 4  07/01/2023     7      1   2023  AA 1856 QK  Sampah        PASAR TEGALREJO
#
#    Netto_kg    Jam    Sopir         Admin            Kecamatan  Musim
# 0      1880  19:22    soleh  Kurniawan BW    Magelang Selatan   Hujan
# 1      1615  19:21  jatmiko  Kurniawan BW       Magelang Utara  Hujan
# 2      2190  19:20    yusuf  Kurniawan BW    Magelang Selatan   Hujan
# 3      1340  19:19     aris  Kurniawan BW  Kecamatan Tegalrejo  Hujan
# 4      1550  19:18   seneng  Kurniawan BW  Kecamatan Tegalrejo  Hujan
#
# ===== SHAPE =====
# Jumlah Baris: 62208, Jumlah Kolom: 13
#
# ===== INFO =====
# <class 'pandas.core.frame.DataFrame'>
# Index: 62208 entries, 0 to 62546
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tanggal     62208 non-null  object
#  1   Hari        62208 non-null  int64
#  2   Bulan       62208 non-null  int64
#  3   Tahun       62208 non-null  int64
#  4   No. Polisi  62208 non-null  object
#  5   Barang      62208 non-null  object
#  6   SUPPLIER    62208 non-null  object
#  7   Netto_kg    62208 non-null  int64
#  8   Jam         62208 non-null  object
#  9   Sopir       62208 non-null  object
#  10  Admin       62208 non-null  object
#  11  Kecamatan   62208 non-null  object
#  12  Musim       62208 non-null  object
# dtypes: int64(4), object(9)
# memory usage: 6.6+ MB
# None
#
# ===== MISSING VALUES =====
# Tanggal       0
# Hari          0
# Bulan         0
# Tahun         0
# No. Polisi    0
# Barang        0
# SUPPLIER      0
# Netto_kg      0
# Jam           0
# Sopir         0
# Admin         0
# Kecamatan     0
# Musim         0
# dtype: int64
#
# ===== DESCRIPTIVE STATISTICS =====
#            Tanggal          Hari         Bulan         Tahun  No. Polisi  \
# count        62208  62208.000000  62208.000000  62208.000000       62208
# unique        1420           NaN           NaN           NaN         116
# top     10/10/2022           NaN           NaN           NaN  AA 9532 HA
# freq            74           NaN           NaN           NaN        2329
# mean           NaN     15.833623      6.468493   2020.462867         NaN
# std            NaN      8.715830      3.418106      1.131607         NaN
# min            NaN      1.000000      1.000000   2019.000000         NaN
# 25%            NaN      8.000000      3.000000   2019.000000         NaN
# 50%            NaN     16.000000      7.000000   2020.000000         NaN
# 75%            NaN     23.000000      9.000000   2021.000000         NaN
# max            NaN     31.000000     12.000000   2023.000000         NaN
#
#         Barang           SUPPLIER      Netto_kg    Jam  Sopir  Admin  \
# count    62208              62208  62208.000000  62208  62208  62208
# unique       3                 65           NaN    758   2633    118
# top     Sampah  DLH KOTA MAGELANG           NaN  10:18      A      D
# freq     60092              13554           NaN    306  16081  15095
# mean       NaN                NaN   1542.570827    NaN    NaN    NaN
# std        NaN                NaN   1332.827948    NaN    NaN    NaN
# min        NaN                NaN      2.000000    NaN    NaN    NaN
# 25%        NaN                NaN    580.000000    NaN    NaN    NaN
# 50%        NaN                NaN   1075.000000    NaN    NaN    NaN
# 75%        NaN                NaN   2030.000000    NaN    NaN    NaN
# max        NaN                NaN  12670.000000    NaN    NaN    NaN
#
#              Kecamatan    Musim
# count            62208    62208
# unique               5        2
# top     Magelang Utara  Kemarau
# freq             29445    31929
# mean               NaN      NaN
# std                NaN      NaN
# min                NaN      NaN
# 25%                NaN      NaN
# 50%                NaN      NaN
# 75%                NaN      NaN
# max                NaN      NaN
#
# ===== UNIQUE VALUE COUNTS =====
# Tanggal: 1420 nilai unik
# Hari: 31 nilai unik
# Bulan: 12 nilai unik
# Tahun: 5 nilai unik
# No. Polisi: 116 nilai unik
# Barang: 3 nilai unik
# SUPPLIER: 65 nilai unik
# Netto_kg: 1274 nilai unik
# Jam: 758 nilai unik
# Sopir: 2633 nilai unik
# Admin: 118 nilai unik
# Kecamatan: 5 nilai unik
# Musim: 2 nilai unik
#
# ===== SAMPLE UNIQUE VALUES (KATEGORIK) =====
# Tanggal: ['07/01/2023' '06/01/2023' '05/01/2023' '04/01/2023' '03/01/2023']
# No. Polisi: ['AA 8013 XA' 'AB 9699 WE' 'AA 8066 XA' 'AA 1975 QH' 'AA 1856 QK']
# Barang: ['Sampah' 'Sampah Terpilah' 0]
# SUPPLIER: ['PASAR REJOWINANGUN' 'PERUM DEPKES MAGELANG' 'DEPO TIDAR SELATAN'
#  'SOROBAYAN BANYUURIP' 'PASAR TEGALREJO']
# Jam: ['19:22' '19:21' '19:20' '19:19' '19:18']
# Sopir: ['soleh' 'jatmiko' 'yusuf' 'aris' 'seneng']
# Admin: ['Kurniawan BW' 'Eksta Gama Pratama Y' 'Ade' 'g' 'G']
# Kecamatan: ['Magelang Selatan ' 'Magelang Utara' 'Kecamatan Tegalrejo'
#  'Magelang Tengah' 'Magelang Selatan']
# Musim: ['Hujan' 'Kemarau']
